# %% [raw]
# ---
# description: This module contains functions that would only add clutter to the flow
#   of the other modules development story and so they, and their descriptions will
#   sit here
# output-file: tools.html
# title: Tools
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
