# %% [raw]
# ---
# description: This module will help manage loading exports
# output-file: models.html
# title: FootballManager Data models
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
